# %%
import re

# %%
with open(f"soldiers.txt", "r") as file:
    text = file.read()

# %%
# Out:
# sprite = 7
# color = {
#  200 187 157
# }
# strata = poor
# state_capital_only = yes
# can_be_recruited = yes
#
# rebel =
# {
# 	cavalry = 0.2
# 	artillery = 0.01
# 	cuirassier = 0.05
# 	dragoon = 0.05
# 	guard = 0.15
# 	hussar = 0.05
# 	infantry = 0.3
# 	irregular = 0
#
# }
#
# life_needs_income = {
# 	type = military
# 	weight = 1.5
#
# }
#
# everyday_needs_income = {
# 	type = military
# 	weight = 1.5
#
# }
#
# luxury_needs_income =
# {
# 	type = reforms
# 	weight = 1
#
#
# }
#
# life_needs = {
# 	canned_food = 6
#
# }
# everyday_needs = {
# 	iron = 2
# 	copper = 1
# 	coal = 1
# 	sugar = 10
# 	tea = 10
# 	cement = 1
# 	liquor = 6
# 	regular_clothes = 5
# 	furniture = 2
# 	cigarettes = 3
# 	shoes = 5
# 	print = 3
#
# }
# luxury_needs = {
# 	boots = 10
# 	opium  = 5
# 	coffee = 10
# 	spices = 5
# 	automobiles = 10
# 	telephones = 10
# 	wine = 10
# 	cigars = 10
# 	fuel = 10
# 	radio = 10
# 	electric_power = 15
#
# }
#
#
# country_migration_target =
# {
# 	factor = 0.01
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([0, 1, 2, 3, 4, 5, 10], marker = "o", ls = "")

plt.grid(True)
