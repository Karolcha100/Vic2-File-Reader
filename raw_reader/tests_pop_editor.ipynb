# %%
from pops_reader import Reader
import json

# %%
with open(f"../example_game_files/soldiers.txt", "r") as file:
    text = file.read()

reader = Reader(True)

# %%
text = "soldiers = {\n" + text + "\n}"

# %%
translation = reader.translate_text(text)

# %%
json.dumps(translation)
# Out:
# '{"sprite": "7", "color": "200 187 157", "strata": "poor", "state_capital_only": "yes", "can_be_recruited": "yes", "rebel-cavalry": "0.2", "rebel-artillery": "0.01", "rebel-cuirassier": "0.05", "rebel-dragoon": "0.05", "rebel-guard": "0.15", "rebel-hussar": "0.05", "rebel-infantry": "0.3", "rebel-irregular": "0", "life_needs_income-type": "military", "life_needs_income-weight": "1.5", "everyday_needs_income-type": "military", "everyday_needs_income-weight": "1.5", "luxury_needs_income-type": "reforms", "luxury_needs_income-weight": "1", "life_needs-canned_food": "6", "everyday_needs-iron": "2", "everyday_needs-copper": "1", "everyday_needs-coal": "1", "everyday_needs-sugar": "10", "everyday_needs-tea": "10", "everyday_needs-cement": "1", "everyday_needs-liquor": "6", "everyday_needs-regular_clothes": "5", "everyday_needs-furniture": "2", "everyday_needs-cigarettes": "3", "everyday_needs-shoes": "5", "everyday_needs-print": "3", "luxury_needs-boots": "10", "luxury_needs-opium": "5", "
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([0, 1, 2, 3, 4, 5, 10], marker = "o", ls = "")

plt.grid(True)
